# %% [markdown]
# ## Exercise: Analyzing and Visualizing Data with Matplotlib, Pandas, and NumPy
#
# The Boston Housing Dataset is a derived from information collected by the U.S. Census Service concerning housing in the area of Boston MA. The following describes the dataset columns:
#
# - CRIM - per capita crime rate by town
# - ZN - proportion of residential land zoned for lots over 25,000 sq.ft.
# - INDUS - proportion of non-retail business acres per town.
# - CHAS - Charles River dummy variable (1 if tract bounds river; 0 otherwise)
# - NOX - nitric oxides concentration (parts per 10 million)
# - RM - average number of rooms per dwelling
# - AGE - proportion of owner-occupied units built prior to 1940
# - DIS - weighted distances to five Boston employment centres
# - RAD - index of accessibility to radial highways
# - TAX - full-value property-tax rate per $10,000
# - PTRATIO - pupil-teacher ratio by town
# - B - 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
# - LSTAT - % lower status of the population
# - MEDV - Median value of owner-occupied homes in $1000's
#
# ### Part 1: Data Preparation
#
# In this part of the exercise, you will use Pandas and NumPy to load and preprocess data. For this exercise, we will use a dataset of housing prices in Boston.
#
# 1.  Download the Boston Housing dataset from [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/machine-learning-databases/housing/housing.data) and save it to your local computer.
# 2.  Load the dataset into a Pandas DataFrame and examine its contents. The dataset should have 506 rows and 14 columns.
# 3.  Use NumPy to calculate some basic statistics about the dataset, such as the mean, median, standard deviation, minimum, and maximum values of each column.
# 4.  Clean the dataset by removing any missing or invalid values. You can use Pandas' `dropna()` method for this.

# %%
# !pip install pandas yfinance matplotlib seaborn
# Out:
# Collecting pandas
#   Downloading pandas-2.2.1-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Collecting yfinance
#   Downloading yfinance-0.2.37-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: matplotlib in c:\users\a507\documents\jip\labs\lib\site-packages (3.8.3)
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy<2,>=1.23.2 in c:\users\a507\documents\jip\labs\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\a507\documents\jip\labs\lib\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: requests>=2.31 in c:\users\a507\documents\jip\labs\lib\site-packages (from yfinance) (2.31.0)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Downloading multitasking-0.0.11-py3-none-any.whl.metadata (5.5 kB)
# Collecting lxml>=4.9.1 (from yfinance)
#   Downloading lxml-5.1.0-cp311-cp311-win_amd64.whl.metadata (3.6 kB)
# Collecting appdirs>=1.4.4 (from yfinance)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting frozendict>=2.3.4 (from yfinance)
#   Downloading frozendict-2.4.0.tar.gz (314 kB)
#      ---------------------------------------- 0.0/314.6 kB ? eta -:--:--
#      -------------------------------------  307.2/314.6 kB 6.3 MB/s eta 0:00:01
#      -------------------------------------- 314.6/314.6 kB 4.9 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting peewee>=3.16.2 (from yfinance)
#   Downloading peewee-3.17.1.tar.gz (3.0 MB)
#      ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#      ---------- ----------------------------- 0.7/3.0 MB 23.8 MB/s eta 0:00:01
#      ------------- -------------------------- 1.0/3.0 MB 16.0 MB/s eta 0:00:01
#      ----------------------- ---------------- 1.7/3.0 MB 12.1 MB/s eta 0:00:01
#      -------------------------------- ------- 2.4/3.0 MB 14.0 MB/s eta 0:00:01
#      ---------------------------------------  2.9/3.0 MB 13.5 MB/s eta 0:00:01
#      ---------------------------------------  2.9/3.0 MB 13.5 MB/s eta 0:00:01
#      ---------------------------------------- 3.0/3.0 MB 10.5 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\a507\documents\jip\labs\lib\site-packages (from yfinance) (4.12.3)
# Collecting html5lib>=1.1 (from yfinance)
#   Downloading html5lib-1.1-py2.py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\a507\documents\jip\labs\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\a507\documents\jip\labs\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\a507\documents\jip\labs\lib\site-packages (from matplotlib) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\a507\documents\jip\labs\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\a507\documents\jip\labs\lib\site-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=8 in c:\users\a507\documents\jip\labs\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\a507\documents\jip\labs\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\a507\documents\jip\labs\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: six>=1.9 in c:\users\a507\documents\jip\labs\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\a507\documents\jip\labs\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\a507\documents\jip\labs\lib\site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\a507\documents\jip\labs\lib\site-packages (from requests>=2.31->yfinance) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\a507\documents\jip\labs\lib\site-packages (from requests>=2.31->yfinance) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\a507\documents\jip\labs\lib\site-packages (from requests>=2.31->yfinance) (2024.2.2)
# Downloading pandas-2.2.1-cp311-cp311-win_amd64.whl (11.6 MB)
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#    ---------------------------------------- 0.1/11.6 MB 8.3 MB/s eta 0:00:02
#    -- ------------------------------------- 0.6/11.6 MB 6.8 MB/s eta 0:00:02
#    -- ------------------------------------- 0.7/11.6 MB 7.4 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.2/11.6 MB 6.5 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.5/11.6 MB 7.0 MB/s eta 0:00:02
#    ------ --------------------------------- 1.8/11.6 MB 6.9 MB/s eta 0:00:02
#    ------- -------------------------------- 2.2/11.6 MB 6.9 MB/s eta 0:00:02
#    -------- ------------------------------- 2.5/11.6 MB 6.6 MB/s eta 0:00:02
#    --------- ------------------------------ 2.8/11.6 MB 6.8 MB/s eta 0:00:02
#    ---------- ----------------------------- 3.1/11.6 MB 6.8 MB/s eta 0:00:02
#    ----------- ---------------------------- 3.4/11.6 MB 6.6 MB/s eta 0:00:02
#    ------------- -------------------------- 3.9/11.6 MB 6.7 MB/s eta 0:00:02
#    -------------- ------------------------- 4.2/11.6 MB 6.8 MB/s eta 0:00:02
#    --------------- ------------------------ 4.6/11.6 MB 6.8 MB/s eta 0:00:02
#    ----------------- ---------------------- 5.0/11.6 MB 6.9 MB/s eta 0:00:01
#    ----------------- ---------------------- 5.1/11.6 MB 7.0 MB/s eta 0:00:01
#    ------------------- -------------------- 5.6/11.6 MB 6.9 MB/s eta 0:00:01
#    -------------------- ------------------- 5.9/11.6 MB 6.9 MB/s eta 0:00:01
#    --------------------- ------------------ 6.2/11.6 MB 6.8 MB/s eta 0:00:01
#    ---------------------- ----------------- 6.6/11.6 MB 6.9 MB/s eta 0:00:01
#    ----------------------- ---------------- 6.9/11.6 MB 6.9 MB/s eta 0:00:01
#    ------------------------ --------------- 7.2/11.6 MB 6.9 MB/s eta 0:00:01
#    ------------------------- -------------- 7.5/11.6 MB 6.9 MB/s eta 0:00:01
#    -------------------------- ------------- 7.8/11.6 MB 6.8 MB/s eta 0:00:01
#    ---------------------------- ----------- 8.2/11.6 MB 6.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 8.7/11.6 MB 7.0 MB/s eta 0:00:01
#    ------------------------------- -------- 9.2/11.6 MB 7.2 MB/s eta 0:00:01
#    --------------------------------- ------ 9.7/11.6 MB 7.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 10.2/11.6 MB 7.4 MB/s eta 0:00:01
#    ------------------------------------- -- 10.8/11.6 MB 7.6 MB/s eta 0:00:01
#    -------------------------------------- - 11.3/11.6 MB 7.8 MB/s eta 0:00:01
#    ---------------------------------------  11.6/11.6 MB 7.9 MB/s eta 0:00:01
#    ---------------------------------------  11.6/11.6 MB 7.9 MB/s eta 0:00:01
#    ---------------------------------------- 11.6/11.6 MB 7.3 MB/s eta 0:00:00
# Downloading yfinance-0.2.37-py2.py3-none-any.whl (72 kB)
#    ---------------------------------------- 0.0/73.0 kB ? eta -:--:--
#    ---------------------------------------- 73.0/73.0 kB 2.0 MB/s eta 0:00:00
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    ---------------------------------------- 294.9/294.9 kB 9.2 MB/s eta 0:00:00
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
#    ---------------------------------------- 0.0/112.2 kB ? eta -:--:--
#    ---------------------------------------- 112.2/112.2 kB 6.8 MB/s eta 0:00:00
# Downloading lxml-5.1.0-cp311-cp311-win_amd64.whl (3.9 MB)
#    ---------------------------------------- 0.0/3.9 MB ? eta -:--:--
#    ----- ---------------------------------- 0.5/3.9 MB 16.5 MB/s eta 0:00:01
#    ---------- ----------------------------- 1.0/3.9 MB 13.3 MB/s eta 0:00:01
#    ---------------- ----------------------- 1.6/3.9 MB 12.5 MB/s eta 0:00:01
#    --------------------- ------------------ 2.1/3.9 MB 12.1 MB/s eta 0:00:01
#    -------------------------- ------------- 2.6/3.9 MB 12.0 MB/s eta 0:00:01
#    --------------------------------- ------ 3.3/3.9 MB 11.6 MB/s eta 0:00:01
#    -------------------------------------- - 3.8/3.9 MB 12.0 MB/s eta 0:00:01
#    ---------------------------------------  3.9/3.9 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------  3.9/3.9 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------- 3.9/3.9 MB 8.9 MB/s eta 0:00:00
# Downloading multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# Downloading pytz-2024.1-py2.py3-none-any.whl (505 kB)
#    ---------------------------------------- 0.0/505.5 kB ? eta -:--:--
#    ----------------------------------- --- 460.8/505.5 kB 14.5 MB/s eta 0:00:01
#    --------------------------------------- 505.5/505.5 kB 10.5 MB/s eta 0:00:00
# Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#    ---------------------------------------- 0.0/345.4 kB ? eta -:--:--
#    --------------------------------------- 345.4/345.4 kB 10.8 MB/s eta 0:00:00
# Building wheels for collected packages: frozendict, peewee
#   Building wheel for frozendict (pyproject.toml): started
#   Building wheel for frozendict (pyproject.toml): finished with status 'done'
#   Created wheel for frozendict: filename=frozendict-2.4.0-py3-none-any.whl size=15471 sha256=054a5230bca28b0bc0aba5e2f2c53c1aada118635e2522df75ee663e99dd949a
#   Stored in directory: c:\users\a507\appdata\local\pip\cache\wheels\31\dd\81\a814e6f8cde8a1bbc1f088fdc273943371f10478b91a605e14
#   Building wheel for peewee (pyproject.toml): started
#   Building wheel for peewee (pyproject.toml): finished with status 'done'
#   Created wheel for peewee: filename=peewee-3.17.1-py3-none-any.whl size=136948 sha256=7f018b766749c75e1cf3f81b26b7586c600b2a700c3abc91a9399a4ccb978a3f
#   Stored in directory: c:\users\a507\appdata\local\pip\cache\wheels\33\d2\ca\79b9807826bc7ef0b86a1ee28c372daaf073f9aa8756eedd7f
# Successfully built frozendict peewee
# Installing collected packages: pytz, peewee, multitasking, appdirs, tzdata, lxml, html5lib, frozendict, pandas, yfinance, seaborn
# Successfully installed appdirs-1.4.4 frozendict-2.4.0 html5lib-1.1 lxml-5.1.0 multitasking-0.0.11 pandas-2.2.1 peewee-3.17.1 pytz-2024.1 seaborn-0.13.2 tzdata-2024.1 yfinance-0.2.37

# %%
import pandas as pd

#Load the dataset into a dataframe
names = ["CRIM", "ZN" , "INDUS", "CHAS", "NOX", "RM", "AGE", "DIS", "RAD", "TAX", "PTRATIO", "B", "LSTAT", "MEDV"]

df = pd.read_csv("housing.data", delim_whitespace=True, header=None, names=names)

#Examine the contents of the DataFrame
print(df.head())
print(df.shape)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2
# (506, 14)
# C:\Users\A507\AppData\Local\Temp\ipykernel_8900\2378882149.py:5: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv("housing.data", delim_whitespace=True, header=None, names=names)

# %%
import numpy as np

mean = np.mean(df, axis=0)
median = np.median(df,axis=0)
std = np.std(df,axis=0)
minimum = np.min(df,axis=0)
maximum = np.max(df,axis=0)

#print("Mean:\n", mean)
#print("Median:\n", median)
#print("Standard deviation:\n", std)
#print("Minimum:\n", minimum)
print("Maximum:\n", maximum)
# Out:
# Maximum:
#  CRIM        88.9762
# ZN         100.0000
# INDUS       27.7400
# CHAS         1.0000
# NOX          0.8710
# RM           8.7800
# AGE        100.0000
# DIS         12.1265
# RAD         24.0000
# TAX        711.0000
# PTRATIO     22.0000
# B          396.9000
# LSTAT       37.9700
# MEDV        50.0000
# dtype: float64

# %%
import pandas as pd

newdf=df.dropna()
print(newdf)
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %% [markdown]
# ### Part 2: Data Visualization
#
# In this part of the exercise, you will use Matplotlib to create some visualizations of the housing data.
#
# 1.  Create a scatter plot of the housing prices (`MEDV`) versus the number of rooms (`RM`). Label the axes and add a title to the plot.
# 2.  Create a histogram of the housing prices (`MEDV`). Label the axes and add a title to the plot.
# 3.  Create a box plot of the housing prices (`MEDV`) grouped by the proximity to employment centers (`DIS`). Label the axes and add a title to the plot.

# %%
import matplotlib.pyplot as plt

plt.scatter(df["RM"], df["MEDV"])
plt.title("Housing price per room number")
plt.xlabel("Room number")
plt.ylabel("Housing price")
plt.show()
# Out:
# Text(0, 0.5, 'Housing price')

# %%
plt.hist(df["MEDV"])
plt.title("Housing price histogram")
plt.xlabel("Housing price")
plt.ylabel("Frequency")
plt.show()

# %%
plt.boxplot([df["MEDV"][df["DIS"] <= 2],df["MEDV"][df["DIS"] > 2]])
plt.xticks([1,2],["Near Employment Center", "Far from employment centers"])
plt.title("Housing prices by proximity to employment centers")
plt.xlabel("Proximity to employment centers")
plt.ylabel("Housing prices")
plt.show()

# %% [markdown]
# ### Part 3: Data Analysis
#
# In this part of the exercise, you will use Pandas and NumPy to perform some basic data analysis on the housing data.
#
# 1.  Calculate the correlation coefficient between the housing prices (`MEDV`) and the number of rooms (`RM`) using NumPy's `corrcoef()` method.
# 2.  Calculate the mean housing price (`MEDV`) for each neighborhood (`CHAS`). You can use Pandas' `groupby()` method for this.
# 3.  Calculate the percentage of houses that have more than 7 rooms (`RM`). You can use Pandas' `value_counts()` method for this.

# %%
corrCoff = np.corrcoef(df["MEDV"], df["RM"])[0, 1]
print(f"Correlation coefficient between housing price and number of rooms: {corrCoff:.2f}")

mean_per_neig = df.groupby("CHAS")["MEDV"].mean()
print(f"\nMean housing price for each neighborhood: {mean_per_neig}")

more_than_7 = (df["RM"] > 7).value_counts(normalize=True) * 100
print((df["RM"]>7).value_counts(normalize=True))
print(f"\nPercantage of houses with more than 7 rooms: {more_than_7[True]:.2f}%")
# Out:
# Correlation coefficient between housing price and number of rooms: 0.70
#
# Mean housing price for each neighborhood: CHAS
# 0    22.093843
# 1    28.440000
# Name: MEDV, dtype: float64
# RM
# False    0.873518
# True     0.126482
# Name: proportion, dtype: float64
#
# Percantage of houses with more than 7 rooms: 12.65%

# %% [markdown]
# ### Part 4: Putting it all together
#
# In this final part of the exercise, you will use all three libraries to create a complete data analysis and visualization pipeline.
#
# 1.  Load the dataset and preprocess it as before.
# 2.  Create the scatter plot and histogram as before.
# 3.  Calculate the correlation coefficient between the housing prices and the number of rooms as before.
# 4.  Group the data by the proximity to employment centers and calculate the mean housing prices as before.
# 5.  Create a bar chart of the mean housing prices by proximity to employment centers. Label the axes and add a title to the plot.
